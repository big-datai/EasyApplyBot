# %%
from database_tools import DatabaseTools
db = DatabaseTools()

# Select all the tables in the database
db.list_tables()
# Out:
# Listing tables in database: /Users/admin1/EasyApplyBot/indeed_job_scraper/indeed.db
# ['search_sessions', 'job_postings', 'job_details']

# %%
# Select the records that were collected today
df = db.sql_to_df("select * from job_postings where date(timestamp) = date('now')")
df
# Out:
#     id  session_id         job_unique_id  \
# 0    1           1  job_b8b2913091c8a5cf
# 1    2           1  job_3a1d126cbeeeb8b4
# 2    3           1  job_2672fe4a82ec1337
# 3    4           1  job_48e638a32a2b952c
# 4    5           1  job_b18b612e04c84727
# ..  ..         ...                   ...
# 69  70           1  job_911c7dd3c4bda415
# 70  71           1  job_119eba7ebd418dd4
# 71  72           1  job_6a26263be8ef1e2b
# 72  73           1  job_3077557fcc7c7ad7
# 73  74           1  job_7bcb0a3c17530853
#
#                                  job_title  \
# 0                 PlainID Business Analyst
# 1              WIDA Data Warehouse Analyst
# 2                       Staff Data Analyst
# 3                      MLS Data Analyst II
# 4               Curam Business Analyst - A
# ..                                     ...
# 69     Decision Support Analyst 3 (REMOTE)
# 70      Product Management Support Analyst
# 71  Financial Analyst (Hybrid - Wisconsin)
# 72                 Program Control Analyst
# 73     Principal - Sales Analytics Analyst
#
#                                              job_link  \
# 0   https://www.indeed.com/rc/clk?jk=b8b2913091c8a...
# 1   https://www.indeed.com/rc/clk?jk=3a1d126cbeeeb...
# 2   https://www.indeed.com/rc/clk?jk=2672fe4a82ec1...
# 3   https://www.indeed.com/rc/clk?jk=48e638a32a2b9...
# 4   https://www.indeed.com/rc/clk?jk=b18b612e04c84...
# ..                                                ...
# 69  https://www.indeed.com/rc/clk?jk=911c7dd3c4bda...
# 70  https://www.indeed.com/rc/clk?jk=119eba7ebd418...
# 71  https://www.indeed.com/rc/clk?jk=6a26263be8ef1...
# 72  https://www.indeed.com/rc/clk?jk=3077557fcc7c7...
# 73  https://www.indeed.com/rc/clk?jk=7bcb0a3c17530...
#
#                                       job_description            timestamp
# 0   PlainID Business Analyst\n====================...  2024-06-23 21:30:50
# 1   WIDA Data Warehouse Analyst\n=================...  2024-06-23 21:30:50
# 2   ![Honor logo](https://d2q79iu7y748jz.cloudfron...  2024-06-23 21:30:50
# 3   MLS Data Analyst II\n===================\n\n[A...  2024-06-23 21:30:50
# 4   Curam Business Analyst - A\n==================...  2024-06-23 21:30:50
# ..                                                ...                  ...
# 69                                               None  2024-06-23 21:30:58
# 70                                               None  2024-06-23 21:30:58
# 71                                               None  2024-06-23 21:30:58
# 72                                               None  2024-06-23 21:30:58
# 73                                               None  2024-06-23 21:30:58
#
# [74 rows x 7 columns]

# %%
# View a single job description
print(df.loc[0].job_description)
# Out:
# PlainID Business Analyst
# ========================
#
# [Purple Drive Technologies](https://www.indeed.com/cmp/Purple-Drive-Technologies?campaignid=mobvjcmp&from=mobviewjob&tk=1i13g4v5ujkt1801&fromjk=b8b2913091c8a5cf)3.8 out of 5RemoteContract[Purple Drive Technologies
# -------------------------
#
# 4 reviewsRead what people are saying about working here.](https://www.indeed.com/cmp/Purple-Drive-Technologies/reviews?campaignid=mobvjcmp&cmpratingc=mobviewjob&from=mobviewjob&tk=1i13g4v5ujkt1801&fromjk=b8b2913091c8a5cf&jt=PlainID+Business+Analyst)Profile insights
# ----------------
#
# Find out how your skills align with the job description### Skills
#
# Do you have experience in **Unit testing**?YesNo### Education
#
# Do you have a **Bachelor's degree**?YesNo&nbsp;Job details
# -----------
#
# Here’s how the job details align with your [profile](https://profile.indeed.com/).### Job type
#
# * Contract
# &nbsp;Location
# --------
#
# Remote&nbsp;Full job description
# --------------------
#
# **Role – PlainID Business Analyst**
#
#
# **Location – Remote**
#
#
# **Mandatory Skills: SailPoint Identity Mgmt and Governance**
#
#
# Job Description:
#
#
# * 10+ years of overall IT experience and in those “last 2+ years of experience must have worked as a Business Analyst driving the adoption of PlainID”, policy-based access control solution in a medium / large scale enterprise.
# * Experienced in IT Business Analysis domain area including the below listed ones.
# * Gathering requirements for enforcing policy-based fine-grained access control from the enterprise applications team using the established intake processes.
# * Documenting the gathered requirements as user stories in Jira software in clear format including the acceptance criteria & getting business sign-off on the requirements.
# * Creating Policies to meet the business requirements in PlainID administration console in lower environments.
# * Working with application development team in successfully conducting Unit Testing, SIT, UAT and rolling out to production rollout.
# * Agile development methodology and associated processes and tools such as Jira, postman and ServiceNow.
# * BA / Solution architect certification from the PlainID is a big plus.
# * Must have excellent written, oral communication skills to be able to effectively communicate with both the management and technical stakeholders.
# * Should be self-driven and work along with the team to achieve the project timelines.
#
#
# Job Type: Contract
#
#
# Work Location: Remote
#
# If you require alternative methods of application or screening, you must approach the employer directly to request this as Indeed is not responsible for the employer's application process.Apply nowsave-icon&nbsp;Report job

# %%
# Print the job description with the links removed, if you're trying to save on tokens (for ai stuff)
from indeed_scraper import IndeedScraper
scraper = IndeedScraper()
print(df.loc[0].job_description)
# Out:
# PlainID Business Analyst
# ========================
#
# [Purple Drive Technologies](https://www.indeed.com/cmp/Purple-Drive-Technologies?campaignid=mobvjcmp&from=mobviewjob&tk=1i13g4v5ujkt1801&fromjk=b8b2913091c8a5cf)3.8 out of 5RemoteContract[Purple Drive Technologies
# -------------------------
#
# 4 reviewsRead what people are saying about working here.](https://www.indeed.com/cmp/Purple-Drive-Technologies/reviews?campaignid=mobvjcmp&cmpratingc=mobviewjob&from=mobviewjob&tk=1i13g4v5ujkt1801&fromjk=b8b2913091c8a5cf&jt=PlainID+Business+Analyst)Profile insights
# ----------------
#
# Find out how your skills align with the job description### Skills
#
# Do you have experience in **Unit testing**?YesNo### Education
#
# Do you have a **Bachelor's degree**?YesNo&nbsp;Job details
# -----------
#
# Here’s how the job details align with your [profile](https://profile.indeed.com/).### Job type
#
# * Contract
# &nbsp;Location
# --------
#
# Remote&nbsp;Full job description
# --------------------
#
# **Role – PlainID Business Analyst**
#
#
# **Location – Remote**
#
#
# **Mandatory Skills: SailPoint Identity Mgmt and Governance**
#
#
# Job Description:
#
#
# * 10+ years of overall IT experience and in those “last 2+ years of experience must have worked as a Business Analyst driving the adoption of PlainID”, policy-based access control solution in a medium / large scale enterprise.
# * Experienced in IT Business Analysis domain area including the below listed ones.
# * Gathering requirements for enforcing policy-based fine-grained access control from the enterprise applications team using the established intake processes.
# * Documenting the gathered requirements as user stories in Jira software in clear format including the acceptance criteria & getting business sign-off on the requirements.
# * Creating Policies to meet the business requirements in PlainID administration console in lower environments.
# * Working with application development team in successfully conducting Unit Testing, SIT, UAT and rolling out to production rollout.
# * Agile development methodology and associated processes and tools such as Jira, postman and ServiceNow.
# * BA / Solution architect certification from the PlainID is a big plus.
# * Must have excellent written, oral communication skills to be able to effectively communicate with both the management and technical stakeholders.
# * Should be self-driven and work along with the team to achieve the project timelines.
#
#
# Job Type: Contract
#
#
# Work Location: Remote
#
# If you require alternative methods of application or screening, you must approach the employer directly to request this as Indeed is not responsible for the employer's application process.Apply nowsave-icon&nbsp;Report job
